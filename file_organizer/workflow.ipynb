# %% [markdown]
# # Workflow of File Organizer

# %% [markdown]
# ## Getting Files for a user
#
# - Since mujhe Backend nahi aata, and nahi fe bana hua so, i am taking files from my directory

# %% [markdown]
# ## Orchestrator
#
# - iteratre over files and make the files ready to be fed into the pipeline

# %% [markdown]
# ## File extension checking
#
# - to check the extension of the file before feeding stuff in
# - pehle i was using mime

# %% [markdown]
# ## Edit
#
# - Since file checking main dikkat aa raha tha, imma use hardocde and check it directly bruuuuuh

# %% [markdown]
# ## Content Extraction
#
# - identify karne ke baad file type, we will use correct method/ tool to get stuff out

# %% [markdown]
# ## Cleaning
#
# - getting rid of faltu stuff, so that llm dont hallucinate baad main, so deleting page numbers, header and footers, characters like \n etc

# %% [markdown]
# ## Metadata generation
#
# - storage of critical info like page count, tables persence if any and other stuff which can be used for a better classification

# %% [markdown]
# ## Classification Agent
#
# - classifies the files into generic categories

# %% [markdown]
# ## Grouping Agent
#
# - groups the similar files and decides the sub folders

# %% [markdown]
# ## Renaming agent
#
# - renames files to human friendly easy to read names rather than, IMG1 etc

# %% [markdown]
# ## Path maker
#
# - tool to make sub folders

# %% [markdown]
# ## File mover
#
# - moves the files to the resp foldrs

# %% [markdown]
# ## ZIP maker
#
# - gives stuff in a zip file at the end

# %% [markdown]
# - T3 chat for LLM, free hain
# - agar renaming nahi cahhaiye then ??
# - pipe line main nahi karenge if req
# - open router
# - image ke liye bhi karna hoga

# %% [markdown]
# ## furthur improvement in dis
#
# - Latency due to big size of files
# - tesseract ka installation
# - took flat 8 min for sorting of just 4 files
# - latnecy in llm calls as well
